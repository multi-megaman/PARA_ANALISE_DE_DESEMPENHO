# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML

# Load the CSV file into a DataFrame
file_path_1 = '50p_500r_20x.csv'
df1 = pd.read_csv(file_path_1)
# Extract statistics of each column
statistics1 = df1.describe()

# Load the CSV file into a DataFrame
file_path_2 = '50000p_500r_2x.csv'
df2 = pd.read_csv(file_path_2)
# Extract statistics of each column
statistics2 = df2.describe()

# Create HTML for each column's statistics side by side
html_content = "<div style='display: flex; flex-wrap: wrap;'>"

for column in statistics1.columns:
    html_content += f"""
    <div style='margin: 10px;'>
        <h3>{file_path_1}</h3>
        {statistics1[column].to_frame().to_html()}
    </div>
    <div style='margin: 10px;'>
        <h3>{file_path_2}</h3>
        {statistics2[column].to_frame().to_html()}
    </div>
    <div style='border-left: 1px solid white; padding-left: 10px;'></div>
    """

html_content += "</div>"

# Display the final HTML
display(HTML(html_content))
# Out:
# <div style='display: flex; flex-wrap: wrap;'>
#     <div style='margin: 10px;'>
#         <h3>50p_500r_20x.csv</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tempo de resposta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>9995.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>22.057813</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>12.493809</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.170804</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>11.282481</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>22.093826</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>32.815812</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>44.505760</td>
#     </tr>
#   </tbody>
# </table>
#     </div>
#     <div style='margin: 10px;'>
#         <h3>50000p_500r_2x.csv</h3>
# ...
